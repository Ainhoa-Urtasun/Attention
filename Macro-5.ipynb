# %%
import pandas
import time
import matplotlib.pyplot as plt
import numpy
import seaborn as sns
import statsmodels.api as sm
from scipy import stats

# %% [markdown]
# # Graetz and Michaels 2018 - employment share

# %%
myeuklems = pandas.read_csv('C:/Ainhoa/Macro-Data/myeuklems.txt',sep=',',index_col=0)
myifr = pandas.read_csv('C:/Ainhoa/Macro-Data/myifr.txt',index_col=0)
myipums1 = pandas.read_csv('C:/Ainhoa/Macro-Data/myipums2.txt',index_col=0)
mydata = myifr.merge(myeuklems,on=['Industry-label','Year'],how='inner')
mydata = mydata.merge(myipums1,on=['Industry-label','Year'],how='inner')
mydata
# Out:
#      Year              Industry-label  Installations  Operational stock  \
# 0    2004  Chemical and other mineral           1146               1146
# 1    2004                 Electronics           1307               1307
# 2    2004               Food products            628                628
# 3    2004                   Machinery              0                  0
# 4    2004                       Metal           1378               1378
# ..    ...                         ...            ...                ...
# 131  2020                   Machinery            309               5032
# 132  2020                       Metal           1985              20959
# 133  2020         Other manufacturing            286               1870
# 134  2020                    Textiles             42                292
# 135  2020         Transport equipment          10576             137015
#
#          comp       empe        h_empe    i_ct  i_cult   i_gfcf  ...  i_omach  \
# 0    156600.0  2308900.0  4.635382e+06  1052.0       0  93888.0  ...  28778.0
# 1    148200.0  1767900.0  3.416605e+06  1322.0       0  68863.0  ...  12078.0
# 2     78900.0  1688400.0  3.208441e+06   231.0       0  19530.0  ...  11859.0
# 3     71800.0  1145200.0  2.307567e+06   218.0       0  14279.0  ...   5359.0
# 4    107300.0  1963900.0  3.923814e+06   228.0       0  17053.0  ...  10304.0
# ..        ...        ...           ...     ...     ...      ...  ...      ...
# 131   96500.0  1055000.0  2.061569e+06   164.0       0  27383.0  ...   8388.0
# 132  133100.0  1739500.0  3.413286e+06   237.0       0  32240.0  ...  17715.0
# 133   81500.0  1126100.0  2.213306e+06    95.0       0  20077.0  ...  12887.0
# 134   18300.0   313500.0  6.168384e+05    25.0       0   3177.0  ...   1237.0
# 135  158400.0  1590900.0  3.092513e+06   359.0       0  72073.0  ...  18206.0
#
#         i_rd  i_rstruc  i_soft_db  i_traeq     va_cp       va_pi  \
# 0    52132.0       0.0     3458.0   1354.0  427700.0  187.039236
# 1    43088.0       0.0     7903.0    301.0  236800.0  270.257000
# 2     2703.0       0.0     1319.0    401.0  156300.0   77.161000
# 3     5832.0       0.0     1457.0    254.0  101400.0   86.265000
# 4     3545.0       0.0      792.0    497.0  165500.0   82.188326
# ..       ...       ...        ...      ...       ...         ...
# 131  13711.0       0.0     2146.0    226.0  163400.0  123.624000
# 132   8335.0       0.0     1317.0    419.0  212100.0   98.137596
# 133   2949.0       0.0     1310.0    193.0  143900.0  119.964416
# 134   1310.0       0.0      272.0      8.0   24800.0  110.724505
# 135  38232.0       0.0     6615.0   3724.0  289100.0  112.579318
#
#      High-skill occupations  Low-skill occupations  Other occupations
# 0                  0.087579               0.467793           0.444628
# 1                  0.266830               0.364716           0.368454
# 2                  0.036007               0.562343           0.401650
# 3                  0.120798               0.525706           0.353495
# 4                  0.062739               0.627820           0.309441
# ..                      ...                    ...                ...
# 131                0.168688               0.463114           0.368199
# 132                0.083617               0.582145           0.334239
# 133                0.100010               0.476442           0.423548
# 134                0.061472               0.568345           0.370183
# 135                0.222559               0.485300           0.292141
#
# [136 rows x 23 columns]

# %% [markdown]
# # Robot density as the stock of robots per million hours worked

# %%
mydata = mydata.copy()
mydata['#Robots/H'] = 1000*mydata['Operational stock']/mydata['h_empe']

# %% [markdown]
# # Controls

# %%
mydata = mydata.copy()
mydata['K/wage'] = mydata['i_gfcf']/mydata['comp']
mydata['ICT/K'] = (mydata['i_it']+mydata['i_ct']+mydata['i_soft_db'])/mydata['i_gfcf']

# %% [markdown]
# # Differences - 1 year

# %%
mydf = mydata.sort_values(by=['Industry-label','Year'])
mydf = mydf[['Industry-label','Year','High-skill occupations','Low-skill occupations','Other occupations','#Robots/H','K/wage','ICT/K','h_empe']]
mydf['High-skill occupations'] = mydf.groupby(['Industry-label'])['High-skill occupations'].diff()
mydf['Low-skill occupations'] = mydf.groupby(['Industry-label'])['Low-skill occupations'].diff()
mydf['Other occupations'] = mydf.groupby(['Industry-label'])['Other occupations'].diff()
mydf['#Robots/H'] = mydf.groupby(['Industry-label'])['#Robots/H'].diff()
mydf['K/wage'] = mydf.groupby(['Industry-label'])['K/wage'].diff()
mydf['ICT/K'] = mydf.groupby(['Industry-label'])['ICT/K'].diff()
mydf = mydf.dropna()
mydf
# Out:
#                  Industry-label  Year  High-skill occupations  \
# 8    Chemical and other mineral  2005                0.001629
# 16   Chemical and other mineral  2006                0.000760
# 24   Chemical and other mineral  2007               -0.001151
# 32   Chemical and other mineral  2008                0.004977
# 40   Chemical and other mineral  2009                0.000211
# ..                          ...   ...                     ...
# 103         Transport equipment  2016                0.010070
# 111         Transport equipment  2017                0.001253
# 119         Transport equipment  2018                0.007756
# 127         Transport equipment  2019                0.010706
# 135         Transport equipment  2020                0.017880
#
#      Low-skill occupations  Other occupations  #Robots/H    K/wage  \
# 8                -0.015987           0.014358   0.353475  0.031853
# 16                0.007565          -0.008325   0.373030  0.030236
# 24               -0.002195           0.003346   0.364771  0.154321
# 32               -0.021203           0.016226   0.377907 -0.003953
# 40               -0.007108           0.006896   0.480685 -0.009776
# ..                     ...                ...        ...       ...
# 103              -0.006365          -0.003704   1.584020 -0.013442
# 111              -0.011522           0.010269   0.616620  0.032161
# 119              -0.004186          -0.003570   0.785555 -0.006281
# 127              -0.000536          -0.010170   1.345182 -0.067425
# 135              -0.018645           0.000765   6.157288  0.001869
#
#             ICT/K        h_empe
# 8   -1.836439e-03  4.529687e+06
# 16  -8.116969e-03  4.570039e+06
# 24  -3.365094e-03  4.493075e+06
# 32   5.394018e-03  4.322391e+06
# 40   8.391616e-03  3.805022e+06
# ..            ...           ...
# 103  7.813611e-04  3.366144e+06
# 111  5.901816e-03  3.373123e+06
# 119  1.213320e-08  3.514151e+06
# 127  1.356415e-02  3.491445e+06
# 135 -4.533074e-03  3.092513e+06
#
# [128 rows x 9 columns]

# %% [markdown]
# # Share of employment by industry for each year

# %%
total = mydf.groupby('Year')['h_empe'].transform('sum')
mydf['share'] = mydf['h_empe'] / total

# %% [markdown]
# # Percentile

# %%
mydf['Percentile'] = mydf['#Robots/H'].apply(lambda x: stats.percentileofscore(mydf['#Robots/H'],x))
mydf
# Out:
#                  Industry-label  Year  High-skill occupations  \
# 8    Chemical and other mineral  2005                0.001629
# 16   Chemical and other mineral  2006                0.000760
# 24   Chemical and other mineral  2007               -0.001151
# 32   Chemical and other mineral  2008                0.004977
# 40   Chemical and other mineral  2009                0.000211
# ..                          ...   ...                     ...
# 103         Transport equipment  2016                0.010070
# 111         Transport equipment  2017                0.001253
# 119         Transport equipment  2018                0.007756
# 127         Transport equipment  2019                0.010706
# 135         Transport equipment  2020                0.017880
#
#      Low-skill occupations  Other occupations  #Robots/H    K/wage  \
# 8                -0.015987           0.014358   0.353475  0.031853
# 16                0.007565          -0.008325   0.373030  0.030236
# 24               -0.002195           0.003346   0.364771  0.154321
# 32               -0.021203           0.016226   0.377907 -0.003953
# 40               -0.007108           0.006896   0.480685 -0.009776
# ..                     ...                ...        ...       ...
# 103              -0.006365          -0.003704   1.584020 -0.013442
# 111              -0.011522           0.010269   0.616620  0.032161
# 119              -0.004186          -0.003570   0.785555 -0.006281
# 127              -0.000536          -0.010170   1.345182 -0.067425
# 135              -0.018645           0.000765   6.157288  0.001869
#
#             ICT/K        h_empe     share  Percentile
# 8   -1.836439e-03  4.529687e+06  0.178440    57.81250
# 16  -8.116969e-03  4.570039e+06  0.178628    60.15625
# 24  -3.365094e-03  4.493075e+06  0.178444    59.37500
# 32   5.394018e-03  4.322391e+06  0.178601    60.93750
# 40   8.391616e-03  3.805022e+06  0.181710    68.75000
# ..            ...           ...       ...         ...
# 103  7.813611e-04  3.366144e+06  0.147572    89.06250
# 111  5.901816e-03  3.373123e+06  0.146476    76.56250
# 119  1.213320e-08  3.514151e+06  0.148759    79.68750
# 127  1.356415e-02  3.491445e+06  0.148340    85.93750
# 135 -4.533074e-03  3.092513e+06  0.140896   100.00000
#
# [128 rows x 11 columns]

# %% [markdown]
# # Regression for high-skill occupations

# %%
df = mydf[['High-skill occupations','Percentile','K/wage','ICT/K','share','Year']]
df = df.copy()
df['Percentile'] = df['Percentile']/100
cluster_var = mydf['Industry-label'].astype(str) + '_' + mydf['Year'].astype(str)
y_dummies = pandas.get_dummies(df['Year'])
df = pandas.concat([df,y_dummies],axis=1)
df.drop([2005,'Year'],axis=1,inplace=True)
Y = df[['High-skill occupations']]
X = df.drop(['High-skill occupations','share'],axis=1)

# %%
mod_wls = sm.WLS(Y,X,weights=df['share'])
res_wls = mod_wls.fit(cov_type='cluster',cov_kwds={'groups':cluster_var},use_t=True)
print(res_wls.summary())
# Out:
#                                    WLS Regression Results
# ===========================================================================================
# Dep. Variable:     High-skill occupations   R-squared (uncentered):                   0.482
# Model:                                WLS   Adj. R-squared (uncentered):              0.398
# Method:                     Least Squares   F-statistic:                              6.254
# Date:                    Tue, 01 Aug 2023   Prob (F-statistic):                    9.77e-11
# Time:                            08:07:34   Log-Likelihood:                          497.96
# No. Observations:                     128   AIC:                                     -959.9
# Df Residuals:                         110   BIC:                                     -908.6
# Df Model:                              18
# Covariance Type:                  cluster
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Percentile    -0.0004      0.002     -0.246      0.806      -0.004       0.003
# K/wage         0.0226      0.017      1.312      0.192      -0.012       0.057
# ICT/K         -0.0377      0.046     -0.824      0.412      -0.128       0.053
# 2006          -0.0029      0.003     -0.868      0.387      -0.010       0.004
# 2007          -0.0002      0.001     -0.174      0.862      -0.003       0.002
# 2008           0.0038      0.002      1.542      0.126      -0.001       0.009
# 2009           0.0062      0.003      2.066      0.041       0.000       0.012
# 2010           0.0019      0.002      0.996      0.321      -0.002       0.006
# 2011          -0.0045      0.002     -2.578      0.011      -0.008      -0.001
# 2012           0.0007      0.001      0.456      0.650      -0.002       0.004
# 2013           0.0018      0.002      1.119      0.265      -0.001       0.005
# 2014          -0.0034      0.002     -2.005      0.047      -0.007   -4.38e-05
# 2015           0.0033      0.001      2.279      0.024       0.000       0.006
# 2016           0.0044      0.002      2.434      0.016       0.001       0.008
# 2017          -0.0008      0.002     -0.463      0.644      -0.004       0.003
# 2018           0.0032      0.001      2.157      0.033       0.000       0.006
# 2019           0.0078      0.002      4.038      0.000       0.004       0.012
# 2020           0.0124      0.002      5.237      0.000       0.008       0.017
# ==============================================================================
# Omnibus:                       31.047   Durbin-Watson:                   2.179
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               96.417
# Skew:                          -0.838   Prob(JB):                     1.16e-21
# Kurtosis:                       6.907   Cond. No.                         74.0
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors are robust to cluster correlation (cluster)

# %% [markdown]
# # Regression for low-skill occupations

# %%
df = mydf[['Low-skill occupations','Percentile','K/wage','ICT/K','share','Year']]
df = df.copy()
df['Percentile'] = df['Percentile']/100
cluster_var = mydf['Industry-label'].astype(str) + '_' + mydf['Year'].astype(str)
y_dummies = pandas.get_dummies(df['Year'])
df = pandas.concat([df,y_dummies],axis=1)
df.drop([2005,'Year'],axis=1,inplace=True)
Y = df[['Low-skill occupations']]
X = df.drop(['Low-skill occupations','share'],axis=1)

# %%
mod_wls = sm.WLS(Y,X,weights=df['share'])
res_wls = mod_wls.fit(cov_type='cluster',cov_kwds={'groups':cluster_var},use_t=True)
print(res_wls.summary())
# Out:
#                                   WLS Regression Results
# ==========================================================================================
# Dep. Variable:     Low-skill occupations   R-squared (uncentered):                   0.395
# Model:                               WLS   Adj. R-squared (uncentered):              0.297
# Method:                    Least Squares   F-statistic:                              5.457
# Date:                   Tue, 01 Aug 2023   Prob (F-statistic):                    2.77e-09
# Time:                           08:08:43   Log-Likelihood:                          426.26
# No. Observations:                    128   AIC:                                     -816.5
# Df Residuals:                        110   BIC:                                     -765.2
# Df Model:                             18
# Covariance Type:                 cluster
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Percentile    -0.0004      0.003     -0.125      0.901      -0.007       0.006
# K/wage        -0.0268      0.027     -0.984      0.327      -0.081       0.027
# ICT/K          0.1205      0.081      1.492      0.138      -0.039       0.280
# 2006           0.0065      0.003      1.959      0.052   -6.45e-05       0.013
# 2007          -0.0044      0.003     -1.447      0.150      -0.010       0.002
# 2008          -0.0118      0.004     -2.805      0.006      -0.020      -0.003
# 2009          -0.0147      0.004     -3.447      0.001      -0.023      -0.006
# 2010           0.0028      0.004      0.799      0.426      -0.004       0.010
# 2011           0.0082      0.004      2.130      0.035       0.001       0.016
# 2012           0.0008      0.004      0.232      0.817      -0.006       0.008
# 2013          -0.0013      0.005     -0.261      0.795      -0.012       0.009
# 2014           0.0009      0.004      0.219      0.827      -0.007       0.009
# 2015           0.0011      0.003      0.359      0.720      -0.005       0.007
# 2016          -0.0042      0.004     -1.050      0.296      -0.012       0.004
# 2017          -0.0019      0.004     -0.426      0.671      -0.010       0.007
# 2018          -0.0043      0.002     -2.149      0.034      -0.008      -0.000
# 2019       -5.976e-06      0.002     -0.003      0.998      -0.005       0.005
# 2020          -0.0131      0.003     -3.787      0.000      -0.020      -0.006
# ==============================================================================
# Omnibus:                        0.430   Durbin-Watson:                   2.509
# Prob(Omnibus):                  0.806   Jarque-Bera (JB):                0.324
# Skew:                           0.123   Prob(JB):                        0.850
# Kurtosis:                       2.993   Cond. No.                         74.0
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors are robust to cluster correlation (cluster)

# %% [markdown]
# # Regression for other occupations

# %%
df = mydf[['Other occupations','Percentile','K/wage','ICT/K','share','Year']]
df = df.copy()
df['Percentile'] = df['Percentile']/100
cluster_var = mydf['Industry-label'].astype(str) + '_' + mydf['Year'].astype(str)
y_dummies = pandas.get_dummies(df['Year'])
df = pandas.concat([df,y_dummies],axis=1)
df.drop([2005,'Year'],axis=1,inplace=True)
Y = df[['Other occupations']]
X = df.drop(['Other occupations','share'],axis=1)

# %%
mod_wls = sm.WLS(Y,X,weights=df['share'])
res_wls = mod_wls.fit(cov_type='cluster',cov_kwds={'groups':cluster_var},use_t=True)
print(res_wls.summary())
# Out:
#                                  WLS Regression Results
# =======================================================================================
# Dep. Variable:      Other occupations   R-squared (uncentered):                   0.257
# Model:                            WLS   Adj. R-squared (uncentered):              0.135
# Method:                 Least Squares   F-statistic:                              3.016
# Date:                Tue, 01 Aug 2023   Prob (F-statistic):                    0.000154
# Time:                        08:09:55   Log-Likelihood:                          439.04
# No. Observations:                 128   AIC:                                     -842.1
# Df Residuals:                     110   BIC:                                     -790.7
# Df Model:                          18
# Covariance Type:              cluster
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Percentile     0.0008      0.003      0.264      0.792      -0.005       0.007
# K/wage         0.0042      0.020      0.206      0.837      -0.036       0.045
# ICT/K         -0.0828      0.076     -1.089      0.278      -0.233       0.068
# 2006          -0.0035      0.003     -1.319      0.190      -0.009       0.002
# 2007           0.0046      0.003      1.586      0.115      -0.001       0.010
# 2008           0.0081      0.003      2.473      0.015       0.002       0.015
# 2009           0.0085      0.003      2.642      0.009       0.002       0.015
# 2010          -0.0047      0.003     -1.388      0.168      -0.012       0.002
# 2011          -0.0037      0.003     -1.125      0.263      -0.010       0.003
# 2012          -0.0015      0.003     -0.475      0.636      -0.008       0.005
# 2013          -0.0005      0.004     -0.111      0.912      -0.009       0.008
# 2014           0.0025      0.004      0.632      0.529      -0.005       0.010
# 2015          -0.0044      0.003     -1.439      0.153      -0.010       0.002
# 2016          -0.0002      0.004     -0.063      0.950      -0.008       0.008
# 2017           0.0026      0.004      0.672      0.503      -0.005       0.010
# 2018           0.0011      0.002      0.498      0.619      -0.003       0.006
# 2019          -0.0078      0.003     -2.705      0.008      -0.013      -0.002
# 2020           0.0007      0.003      0.209      0.835      -0.006       0.007
# ==============================================================================
# Omnibus:                        0.172   Durbin-Watson:                   2.789
# Prob(Omnibus):                  0.918   Jarque-Bera (JB):                0.048
# Skew:                          -0.046   Prob(JB):                        0.976
# Kurtosis:                       3.025   Cond. No.                         74.0
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors are robust to cluster correlation (cluster)
