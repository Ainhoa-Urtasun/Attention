# %%
import pandas
import numpy
from numpy import std, correlate, sqrt
from scipy.stats import pearsonr
import statsmodels.api as sm
from statsmodels.stats.mediation import Mediation
from linearmodels import IV2SLS
# %run Table_Summary.ipynb
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from matplotlib.lines import Line2D
plt.style.use('seaborn-whitegrid')
from math import pi
import openpyxl

# %% [markdown]
# # Data

# %%
filepath = 'C:/Ainhoa/Attention/Data/Original_data.txt'
data = pandas.read_csv(filepath,sep='\t')
data.rename(columns={'origi':'Id'},inplace=True)
print(data.shape,'from 2019_05_25_Results.xlxs')
print(data.Year.unique(),'Years')
print(data.Id.nunique(),'Number of firms')
filepath = 'C:/Ainhoa/Attention/Data/Database_secondreviewJIBS.dta'
data1 = pandas.read_stata(filepath)
data1.rename(columns={'id':'Id','year':'Year','country':'Country'},inplace=True)
data1 = data1[['Id','Year','Country']]
data1['Year'] = pandas.to_numeric(data1.Year.astype(str).str[0:4])
print(data1.shape,'to get country')
data = pandas.merge(left=data,right=data1,how='left',on=['Year','Id'])
print(data.Country.unique())
filepath = 'C:/Ainhoa/Attention/Data/2019_05_25_Results_updated.txt'
data2 = pandas.read_csv(filepath,sep='\t')
print(data2.shape,'correction by Elio of market commonality')
data2.rename(columns={'origi':'Id'},inplace=True)
data2 = data2[['Id','Year','Market_commonality']]
data.drop('Market_commonality',axis=1,inplace = True)
data = pandas.merge(left=data,right=data2,how='inner',on=['Year','Id'])
print(data.Non_RD_alliances.sum(),'Total number of Non-RD alliances')
print(data.RD_alliances.sum(),'Total number of RD alliances (hybrid alliances)')
filepath = 'C:/Ainhoa/Attention/Data/Count/Data/count_sim.txt'
data3 = pandas.read_csv(filepath,sep='\t')
data3['SUM'] = data3['geographic']+data3['growth']+data3['product']
data3['GEOGRAPHY0'] = data3.geographic/data3.SUM
data3['GROWTH0'] = data3.growth/data3.SUM
data3['PRODUCT0'] = data3['product']/data3.SUM
data3 = data3[['Id','GEOGRAPHY0','GROWTH0','PRODUCT0']]
data = pandas.merge(left=data,right=data3,how='inner',on=['Id'])
filepath = 'C:/Ainhoa/Attention/Data/Results_def_01_for_Elio.txt'
data4 = pandas.read_csv(filepath,sep='\t')
data4 = data4.iloc[1:1008,[0,1,25,26,27]]
data4.columns = ['Year','Id','PRODUCT','GEOGRAPHY','GROWTH']
data4['Year'] = pandas.to_numeric(data4.Year.astype(str).str[0:4])
print(data4)
data = pandas.merge(left=data,right=data4,how='inner',on=['Year','Id'])
print(data.columns)
data
# Out:
# (1232, 33) from 2019_05_25_Results.xlxs
# [1991 1992 1993 1994 1995 1996 1997 1998 1999 2000 2001 2002 2003 2004
#  2005 2006 2007 2008 2009 2010 2011 2012] Years
# 56 Number of firms
# (1539, 3) to get country
# [nan 'USA' 'Switzerland' 'Netherlands' 'Germany' 'South Africa' 'Japan'
#  'United Kingdom' 'France' 'Australia' 'Ireland' 'Spain' 'Denmark'
#  'Sweden']
# (1232, 34) correction by Elio of market commonality
# 4089.0 Total number of Non-RD alliances
# 7676.0 Total number of RD alliances (hybrid alliances)
#       Year  Id  PRODUCT  GEOGRAPHY    GROWTH
# 1     1995   2     0.00   0.339996  0.660004
# 2     1995   3      NaN        NaN       NaN
# 3     1995   4      NaN        NaN       NaN
# 4     1995   5      NaN        NaN       NaN
# 5     1995   6      NaN        NaN       NaN
# ...    ...  ..      ...        ...       ...
# 1003  2012  52     0.75   0.075352  0.170363
# 1004  2012  53     0.83   0.000000  0.167799
# 1005  2012  54     0.00   0.997644  0.002356
# 1006  2012  55      NaN        NaN       NaN
# 1007  2012  56      NaN        NaN       NaN
#
# [1007 rows x 5 columns]
# Index(['Id', 'Year', 'Age', 'Employees', 'Total_assets', 'Net_sales',
#        'Human_resources_1', 'Human_resources_2', 'Physical_resources_1',
#        'Physical_resources_2', 'Financial_resources_1',
#        'Operating_activities_Net_Cash_Flow',
#        'Investing_activities_Net_Cash_Flow',
#        'Financing_activities_Net_Cash_Flow', 'Social_resources_1',
#        'Social_resources_2', 'Product_scope', 'Firm_size_1', 'Firm_size_2',
#        'Geographc_scope', 'Absorptive_capacity', 'Employees.1',
#        'Total_alliances', 'Non_RD_alliances', 'RD_alliances',
#        'Equity_alliances', 'Absorbed_slack', 'Unabsorbed_slack',
#        'Potential_slack', 'ROS', 'ROA', 'ROE', 'Country', 'Market_commonality',
#        'GEOGRAPHY0', 'GROWTH0', 'PRODUCT0', 'PRODUCT', 'GEOGRAPHY', 'GROWTH'],
#       dtype='object')
#       Id  Year    Age  Employees Total_assets  Net_sales  Human_resources_1  \
# 0      1  1996   94.0    74289.0    13364.000  14236.000              0.192
# 1      1  1997   95.0    75639.0    13238.000  15070.000              0.199
# 2      1  1998   96.0    73564.0    14153.000  15021.000              0.204
# 3      1  1999   97.0    70549.0    13896.000  15659.000              0.222
# 4      1  2000   98.0    75000.0    14522.000  16724.000              0.223
# ...   ..   ...    ...        ...          ...        ...                ...
# 1002  56  2008  148.0    47426.0    44031.724  22833.908              0.481
# 1003  56  2009    NaN        NaN          NaN        NaN                NaN
# 1004  56  2010    NaN        NaN          NaN        NaN                NaN
# 1005  56  2011    NaN        NaN          NaN        NaN                NaN
# 1006  56  2012    NaN        NaN          NaN        NaN                NaN
#
#       Human_resources_2  Physical_resources_1  Physical_resources_2  ...  \
# 0                 5.218              4844.000                 0.340  ...
# 1                 5.019              5034.000                 0.334  ...
# 2                 4.897              5566.000                 0.371  ...
# 3                 4.505              5656.000                 0.361  ...
# 4                 4.485              5823.000                 0.348  ...
# ...                 ...                   ...                   ...  ...
# 1002              2.077             11198.211                 0.490  ...
# 1003                NaN                   NaN                   NaN  ...
# 1004                NaN                   NaN                   NaN  ...
# 1005                NaN                   NaN                   NaN  ...
# 1006                NaN                   NaN                   NaN  ...
#
#         ROA    ROE  Country  Market_commonality  GEOGRAPHY0   GROWTH0  \
# 0     0.114  0.243      USA               0.524    0.183858  0.241124
# 1     0.160  0.358      USA               0.237    0.183858  0.241124
# 2     0.083  0.198      USA               0.360    0.183858  0.241124
# 3     0.127  0.280      USA               0.323    0.183858  0.241124
# 4     0.123  0.273      USA               0.240    0.183858  0.241124
# ...     ...    ...      ...                 ...         ...       ...
# 1002  0.100  0.230  Denmark               0.555    0.237752  0.190167
# 1003    NaN    NaN  Denmark                 NaN    0.237752  0.190167
# 1004    NaN    NaN  Denmark                 NaN    0.237752  0.190167
# 1005    NaN    NaN  Denmark                 NaN    0.237752  0.190167
# 1006    NaN    NaN  Denmark                 NaN    0.237752  0.190167
#
#       PRODUCT0  PRODUCT  GEOGRAPHY    GROWTH
# 0     0.575019      0.0   0.784127  0.215873
# 1     0.575019      0.0   0.774649  0.225351
# 2     0.575019      0.0   0.750883  0.249117
# 3     0.575019      0.0   0.793790  0.206210
# 4     0.575019      0.0   0.788899  0.211101
# ...        ...      ...        ...       ...
# 1002  0.572081      NaN        NaN       NaN
# 1003  0.572081      NaN        NaN       NaN
# 1004  0.572081      NaN        NaN       NaN
# 1005  0.572081      NaN        NaN       NaN
# 1006  0.572081      NaN        NaN       NaN
#
# [1007 rows x 40 columns]

# %% [markdown]
# # Variables

# %%
df = data.copy()
df = df.sort_values(by=['Id','Year'],axis=0,ascending=True)

# UNDERPERFORMANCE MAGNITUDE
df['distance'] = df['ROE'] - df.groupby(['Year']).ROE.transform('mean')
df.loc[(df.distance<0),'Underperformance magnitude']=df['distance']
df.loc[(df.distance>0)|(df.distance==0),'Underperformance magnitude']=0

# UNDERPERFORMANCE DURATION
df['Underperformance duration'] = 0
mylist = []
for firm in range(df.Id.nunique()):
  mylist.append(df.loc[df.Id==firm+1,['Id','Year','Underperformance magnitude','Underperformance duration']].values.tolist())
m = [[0,0,0]]
for firm in range(df.Id.nunique()):
  for i in mylist[firm]: 
    if i[2]<0:
      m.append([i[0],i[1],m[-1][2]+1])
    else:
      m.append([i[0],i[1],i[3]])
del m[0]
print(len(m))
mydf = pandas.DataFrame(m,columns=['Id','Year','Underperformance duration'])
df = df.drop('Underperformance duration',axis=1)
df = pandas.merge(left=df,right=mydf,how='inner',on=['Year','Id'])
print(df.loc[(df.Id==38)|(df.Id==39),['Id','Year','Underperformance magnitude','Underperformance duration']])
df = df.sort_values(by=['Id','Year'], axis=0, ascending=True)

# AMBIDEXTROUS ALLIANCES
print(df.Non_RD_alliances.corr(df.RD_alliances),'correlation between RD alliances and non-RD alliances')
df['Ambidextrous alliances'] = (1/1000)*df.RD_alliances*df.Non_RD_alliances

# ATTENTIONAL FOCUS
df['Attentional focus'] = df[['PRODUCT','GEOGRAPHY','GROWTH']].apply(lambda x: x.std(skipna=True), axis=1)

# CONTROL VARIABLES
df['distance'] = df['ROE'] - df.groupby(['Year']).ROE.transform('mean')
df.loc[(df.distance>0)|(df.distance==0),'Overperformance magnitude']=df['distance']
df.loc[(df.distance<0)|(df.distance==0),'Overperformance magnitude']=0

df['Overperformance duration'] = 0
mylist = []
for firm in range(df.Id.nunique()):
  mylist.append(df.loc[df.Id==firm+1,['Id','Year','Overperformance magnitude','Overperformance duration']].values.tolist())
m = [[0,0,0]]
for firm in range(df.Id.nunique()):
  for i in mylist[firm]: 
    if i[2]>0:
      m.append([i[0],i[1],m[-1][2]+1])
    else:
      m.append([i[0],i[1],i[3]])
del m[0]
print(m)
print(len(m))
mydf = pandas.DataFrame(m,columns=['Id','Year','Overperformance duration'])
df = df.drop('Overperformance duration',axis=1)
df = pandas.merge(left=df,right=mydf,how='inner',on=['Year','Id'])
print(df.loc[(df.Id==38)|(df.Id==39),['Id','Year','Overperformance magnitude','Overperformance duration']])
df = df.sort_values(by=['Id','Year'], axis=0, ascending=True)

df['Absorbed slack'] = df['Absorbed_slack']
df['Unabsorbed slack'] = df['Unabsorbed_slack']
df['Absorptive capacity'] = df['Absorptive_capacity']
df['Market commonality'] = df['Market_commonality']
df['Size'] = numpy.log(df.Employees) 

df
# Out:
# 1007
#      Id  Year  Underperformance magnitude  Underperformance duration
# 665  38  1995                   -0.015244                        5.0
# 666  38  1996                   -0.098000                        6.0
# 667  38  1997                    0.000000                        0.0
# 668  38  1998                   -0.209075                        1.0
# 669  38  1999                   -0.059585                        2.0
# 670  38  2000                   -0.124833                        3.0
# 671  38  2001                   -0.008870                        4.0
# 672  38  2002                    0.000000                        0.0
# 673  38  2003                    0.000000                        0.0
# 674  38  2004                   -0.045434                        1.0
# 675  38  2005                   -0.000642                        2.0
# 676  38  2006                   -0.000154                        3.0
# 677  38  2007                   -0.634098                        4.0
# 678  38  2008                   -0.259360                        5.0
# 679  38  2009                   -0.163826                        6.0
# 680  38  2010                   -0.089444                        7.0
# 681  38  2011                   -0.104333                        8.0
# 682  38  2012                   -0.025738                        9.0
# 683  39  1995                         NaN                        0.0
# 684  39  1996                   -0.111000                        1.0
# 685  39  1997                    0.000000                        0.0
# 686  39  1998                   -0.122075                        1.0
# 687  39  1999                    0.000000                        0.0
# 688  39  2000                    0.000000                        0.0
# 689  39  2001                   -0.028870                        1.0
# 690  39  2002                    0.000000                        0.0
# 691  39  2003                    0.000000                        0.0
# 692  39  2004                    0.000000                        0.0
# 693  39  2005                   -0.048642                        1.0
# 694  39  2006                    0.000000                        0.0
# 695  39  2007                   -0.057098                        1.0
# 696  39  2008                   -0.029360                        2.0
# 697  39  2009                   -0.091826                        3.0
# 698  39  2010                   -0.044444                        4.0
# 699  39  2011                   -0.119333                        5.0
# 700  39  2012                   -0.079738                        6.0
# 0.7259338699988971 correlation between RD alliances and non-RD alliances
# [[1.0, 1996.0, 1], [1.0, 1997.0, 2], [1.0, 1998.0, 0.0], [1.0, 1999.0, 1.0], [1.0, 2000.0, 2.0], [1.0, 2001.0, 3.0], [1.0, 2002.0, 4.0], [1.0, 2003.0, 5.0], [1.0, 2004.0, 6.0], [1.0, 2005.0, 7.0], [1.0, 2006.0, 8.0], [1.0, 2007.0, 9.0], [1.0, 2008.0, 10.0], [1.0, 2009.0, 11.0], [1.0, 2010.0, 12.0], [1.0, 2011.0, 13.0], [1.0, 2012.0, 14.0], [2.0, 1995.0, 15.0], [2.0, 1996.0, 16.0], [2.0, 1997.0, 17.0], [2.0, 1998.0, 18.0], [2
# 2                      0.000000                       0.0           0.252
# 3                      0.092415                       1.0           0.252
# 4                      0.115167                       2.0           0.328
# ...                         ...                       ...             ...
# 1002                   0.037640                       1.0           0.433
# 1003                        NaN                       0.0             NaN
# 1004                        NaN                       0.0             NaN
# 1005                        NaN                       0.0             NaN
# 1006                        NaN                       0.0             NaN
#
#       Unabsorbed slack  Absorptive capacity  Market commonality       Size
# 0                0.196                0.067               0.524  11.215718
# 1                0.120                0.066               0.237  11.233727
# 2                0.121                0.068               0.360  11.205911
# 3                0.115                0.066               0.323  11.164063
# 4                0.635                0.066               0.240  11.225243
# ...                ...                  ...                 ...        ...
# 1002             2.123                0.148               0.555  10.766926
# 1003               NaN                  NaN                 NaN        NaN
# 1004               NaN                  NaN                 NaN        NaN
# 1005               NaN                  NaN                 NaN        NaN
# 1006               NaN                  NaN                 NaN        NaN
#
# [1007 rows x 52 columns]

# %%
dv = ['Underperformance magnitude','Underperformance duration']
iv = ['Ambidextrous alliances','Attentional focus','Overperformance magnitude','Overperformance duration','Absorbed slack','Unabsorbed slack','Absorptive capacity','Market commonality','Size']
mydata = df[dv+iv]
mydata
# Out:
#       Underperformance magnitude  Underperformance duration  \
# 0                       0.000000                        0.0
# 1                       0.000000                        0.0
# 2                      -0.120075                        1.0
# 3                       0.000000                        0.0
# 4                       0.000000                        0.0
# ...                          ...                        ...
# 1002                    0.000000                        0.0
# 1003                         NaN                        0.0
# 1004                         NaN                        0.0
# 1005                         NaN                        0.0
# 1006                         NaN                        0.0
#
#       Ambidextrous alliances  Attentional focus  Overperformance magnitude  \
# 0                      0.000           0.405045                   0.049000
# 1                      0.000           0.398454                   0.228423
# 2                      0.002           0.382460                   0.000000
# 3                      0.000           0.411881                   0.092415
# 4                      0.000           0.408407                   0.115167
# ...                      ...                ...                        ...
# 1002                   0.004                NaN                   0.037640
# 1003                   0.012                NaN                        NaN
# 1004                     NaN                NaN                        NaN
# 1005                     NaN                NaN                        NaN
# 1006                     NaN                NaN                        NaN
#
#       Overperformance duration  Absorbed slack  Unabsorbed slack  \
# 0                          1.0           0.256             0.196
# 1                          2.0           0.253             0.120
# 2                          0.0           0.252             0.121
# 3                          1.0           0.252             0.115
# 4                          2.0           0.328             0.635
# ...                        ...             ...               ...
# 1002                       1.0           0.433             2.123
# 1003                       0.0             NaN               NaN
# 1004                       0.0             NaN               NaN
# 1005                       0.0             NaN               NaN
# 1006                       0.0             NaN               NaN
#
#       Absorptive capacity  Market commonality       Size
# 0                   0.067               0.524  11.215718
# 1                   0.066               0.237  11.233727
# 2                   0.068               0.360  11.205911
# 3                   0.066               0.323  11.164063
# 4                   0.066               0.240  11.225243
# ...                   ...                 ...        ...
# 1002                0.148               0.555  10.766926
# 1003                  NaN                 NaN        NaN
# 1004                  NaN                 NaN        NaN
# 1005                  NaN                 NaN        NaN
# 1006                  NaN                 NaN        NaN
#
# [1007 rows x 11 columns]

# %% [markdown]
# # Table 2

# %%
ds_mean = mydata.agg(['mean','std','count']).T
corr = mydata.corr()
corr = pandas.concat([ds_mean,corr], axis = 1)
corr = corr.applymap('{:.3f}'.format)
corr['statistics'] = ' '
corr.set_index('statistics',append=True,inplace=True)

def pearsonr_pval(x,y):
  return pearsonr(x,y)[1].round(3)
pval = mydata.corr(method=pearsonr_pval)
pval = pval.applymap('{:.3f}'.format)
pval = pval.applymap(lambda x: '(' + x + ')')
pval['statistics'] = 'p-value'
pval.set_index('statistics',append=True,inplace=True)

corr = pandas.concat([corr,pval],axis=0).sort_index(kind='merge').reindex(dv+iv,axis=0,level=0)
corr.to_excel('Table2.xlsx')
corr
# Out:
#                                          mean     std     count  \
#                            statistics
# Underperformance magnitude             -0.098   0.215   904.000
#                            p-value        NaN     NaN       NaN
# Underperformance duration               3.256   5.801  1007.000
#                            p-value        NaN     NaN       NaN
# Ambidextrous alliances                  0.056   0.128   794.000
#                            p-value        NaN     NaN       NaN
# Attentional focus                       0.461   0.102   536.000
#                            p-value        NaN     NaN       NaN
# Overperformance magnitude               0.098   0.333   904.000
#                            p-value        NaN     NaN       NaN
# Overperformance duration                1.741   3.548  1007.000
#                            p-value        NaN     NaN       NaN
# Absorbed slack                          1.966  37.881   679.000
#                            p-value        NaN     NaN       NaN
# Unabsorbed slack                        1.391   1.988   724.000
#                            p-value        NaN     NaN       NaN
# Absorptive capacity                     0.233   0.723   899.000
#                            p-value        NaN     NaN       NaN
# Market commonality                      0.405   0.141   906.000
#                            p-value        NaN     NaN       NaN
# Size                                    9.367   1.765   878.000
#                            p-value        NaN     NaN       NaN
#
#                                       Underperformance magnitude  \
#                            statistics
# Underperformance magnitude                                 1.000
#                            p-value                       (1.000)
# Underperformance duration                                 -0.154
#                            p-value                       (0.000)
# Ambidextrous alliances                                     0.109
#                            p-value                       (0.003)
# Attentional focus                                          0.035
#                            p-value                       (0.422)
# Overperformance magnitude                                  0.136
#                            p-value                       (0.000)
# Overperformance duration                                   0.241
#                            p-value                       (0.000)
# Absorbed slack                                            -0.065
#                            p-value                       (0.094)
# Unabsorbed slack                                          -0.163
#                            p-value                       (0.000)
# Absorptive capacity                                       -0.457
#                            p-value                       (0.000)
# Market commonality                                        -0.083
#                            p-value                       (0.014)
# Size                                                       0.304
#                            p-value                       (0.000)
#
#                                       Underperformance duration  \
#                            statistics
# Underperformance magnitude                               -0.154
#                            p-value                      (0.000)
# Underperformance duration                                 1.000
#                            p-value                      (1.000)
# Ambidextrous alliances                                   -0.161
#                            p-value                      (0.000)
# Attentional focus                                        -0.052
#                            p-value                      (0.225)
# Overperformance magnitude                                -0.179
#                            p-value                      (0.000)
# Overperformance duration                                 -0.276
#                            p-value                      (0.000)
# Absorbed slack                                           -0.011
#                            p-value                      (0.765)
# Unabsorbed slack                                          0.027
#                            p-value                      (0.464)
# Absorptive capacity                                       0.015
#                            p-value                      (0.657)
# Market commonality                                        0.023
#                            p-value                      (0.487)
# Size                                                     -0.162
#                            p-value                      (0.000)
#
#                                       Ambidextrous alliances  \
#                            statistics
# Underperformance magnitude                             0.109
#                            p-value                   (0.003)
# Underperformance duration                             -0.161
#                            p-value                   (0.000)
# Ambidextrous alliances                                 1.000
#                            p-value                   (1.000)
# Attentional focus                                      0.050
#                            p-value                   (0.281)
# Overperformance magnitude                              0.062
#                            p-value                   (0.086)
# Overperformance duration                               0.257
#                            p-value                   (0.000)
# Absorbed slack                                        -0.020
#                            p-value                   (0.627)
# Unabsorbed slack                                      -0.147
#                            p-value                   (0.000)
# Absorptive capacity                                   -0.053
#                            p-value                   (0.146)
# Market commonality                                     0.052
#                            p-value                   (0.150)
# Size                                                   0.264
#                            p-value                   (0.000)
#
#                                       Attentional focus  \
#                            statistics
# Underperformance magnitude                        0.035
#                            p-value              (0.422)
# Underperformance duration                        -0.052
#                            p-value              (0.225)
# Ambidextrous alliances                            0.050
#                            p-value              (0.281)
# Attentional focus                                 1.000
#                            p-value              (1.000)
# Overperformance magnitude                        -0.064
#                            p-value              (0.138)
# Overperformance duration                         -0.155
#                            p-value              (0.000)
# Absorbed slack                                    0.190
#                            p-value              (0.000)
# Unabsorbed slack                                  0.047
#                            p-value              (0.332)
# Absorptive capacity                               0.097
#                            p-value              (0.025)
# Market commonality                               -0.055
#                            p-value              (0.201)
# Size                                              0.003
#                            p-value              (0.945)
#
#                                       Overperformance magnitude  \
#                            statistics
# Underperformance magnitude                                0.136
#                            p-value                      (0.000)
# Underperformance duration                                -0.179
#                            p-value                      (0.000)
# Ambidextrous alliances                                    0.062
#                            p-value                      (0.086)
# Attentional focus                                        -0.064
#                            p-value                      (0.138)
# Overperformance magnitude                                 1.000
#                            p-value                      (1.000)
# Overperformance duration                                  0.323
#                            p-value                      (0.000)
# Absorbed slack                                           -0.014
#                            p-value                      (0.722)
# Unabsorbed slack                                          0.102
#                            p-value                      (0.007)
# Absorptive capacity                                       0.130
#                            p-value                      (0.000)
# Market commonality                                       -0.020
#                            p-value                      (0.560)
# Size                                                      0.035
#                            p-value                      (0.297)
#
#                                       Overperformance duration Absorbed slack  \
#                            statistics
# Underperformance magnitude                               0.241         -0.065
#                            p-value                     (0.000)        (0.094)
# Underperformance duration                               -0.276         -0.011
#                            p-value                     (0.000)        (0.765)
# Ambidextrous alliances                                   0.257         -0.020
#                            p-value                     (0.000)        (0.627)
# Attentional focus                                       -0.155          0.190
#                            p-value                     (0.000)        (0.000)
# Overperformance magnitude                                0.323         -0.014
#                            p-value                     (0.000)        (0.722)
# Overperformance duration                                 1.000         -0.023
#                            p-value                     (1.000)        (0.557)
# Absorbed slack                                          -0.023          1.000
#                            p-value                     (0.557)        (1.000)
# Unabsorbed slack                                        -0.007          0.011
#                            p-value                     (0.849)        (0.771)
# Absorptive capacity                                     -0.062          0.002
#                            p-value                     (0.061)        (0.952)
# Market commonality                                      -0.157         -0.017
#                            p-value                     (0.000)        (0.662)
# Size                                                     0.269         -0.097
#                            p-value                     (0.000)        (0.014)
#
#                                       Unabsorbed slack Absorptive capacity  \
#                            statistics
# Underperformance magnitude                      -0.163              -0.457
#                            p-value             (0.000)             (0.000)
# Underperformance duration                        0.027               0.015
#                            p-value             (0.464)             (0.657)
# Ambidextrous alliances                          -0.147              -0.053
#                            p-value             (0.000)             (0.146)
# Attentional focus                                0.047               0.097
#                            p-value             (0.332)             (0.025)
# Overperformance magnitude                        0.102               0.130
#                            p-value             (0.007)             (0.000)
# Overperformance duration                        -0.007              -0.062
#                            p-value             (0.849)             (0.061)
# Absorbed slack                                   0.011               0.002
#                            p-value             (0.771)             (0.952)
# Unabsorbed slack                                 1.000               0.336
#                            p-value             (1.000)             (0.000)
# Absorptive capacity                              0.336               1.000
#                            p-value             (0.000)             (1.000)
# Market commonality                               0.064               0.086
#                            p-value             (0.092)             (0.011)
# Size                                            -0.369              -0.287
#                            p-value             (0.000)             (0.000)
#
#                                       Market commonality     Size
#                            statistics
# Underperformance magnitude                        -0.083    0.304
#                            p-value               (0.014)  (0.000)
# Underperformance duration                          0.023   -0.162
#                            p-value               (0.487)  (0.000)
# Ambidextrous alliances                             0.052    0.264
#                            p-value               (0.150)  (0.000)
# Attentional focus                                 -0.055    0.003
#                            p-value               (0.201)  (0.945)
# Overperformance magnitude                         -0.020    0.035
#                            p-value               (0.560)  (0.297)
# Overperformance duration                          -0.157    0.269
#                            p-value               (0.000)  (0.000)
# Absorbed slack                                    -0.017   -0.097
#                            p-value               (0.662)  (0.014)
# Unabsorbed slack                                   0.064   -0.369
#                            p-value               (0.092)  (0.000)
# Absorptive capacity                                0.086   -0.287
#                            p-value               (0.011)  (0.000)
# Market commonality                                 1.000    0.035
#                            p-value               (1.000)  (0.306)
# Size                                               0.035    1.000
#                            p-value               (0.306)  (1.000)

# %% [markdown]
# # Preparing data for regression

# %% [markdown]
# https://data.library.virginia.edu/introduction-to-mediation-analysis/

# %%
XY = df[dv+iv+['Id','Year']]
XY = XY.dropna()
X = XY[iv+['Year']]
X = X.copy()
X['Intercept'] = 1
X0 = X.drop(['Attentional focus'],axis=1)

# %%
model0 = sm.OLS(XY['Underperformance magnitude'],X0)
est_model0 = model0.fit(cov_type='hac-groupsum',cov_kwds={'time':XY.set_index('Year').index,'maxlags':5})
print(est_model0.summary())
model1 = sm.OLS(XY['Attentional focus'],X0)
est_model1 = model1.fit(cov_type='hac-groupsum',cov_kwds={'time':XY.set_index('Year').index,'maxlags':5})
print(est_model1.summary())
model2 = sm.OLS(XY['Underperformance magnitude'],X)
est_model2 = model2.fit(cov_type='hac-groupsum',cov_kwds={'time':XY.set_index('Year').index,'maxlags':5})
print(est_model2.summary())
mediation = Mediation(model2,model1,'Ambidextrous alliances','Attentional focus').fit(n_rep=1000)
print(mediation.summary())
# Out:
#                                 OLS Regression Results
# ======================================================================================
# Dep. Variable:     Underperformance magnitude   R-squared:                       0.371
# Model:                                    OLS   Adj. R-squared:                  0.355
# Method:                         Least Squares   F-statistic:                     180.2
# Date:                        Wed, 14 Jun 2023   Prob (F-statistic):           8.99e-28
# Time:                                10:45:27   Log-Likelihood:                 189.85
# No. Observations:                         365   AIC:                            -359.7
# Df Residuals:                             355   BIC:                            -320.7
# Df Model:                                   9
# Covariance Type:                 hac-groupsum
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Ambidextrous alliances        0.0491      0.011      4.371      0.000       0.027       0.071
# Overperformance magnitude     0.3116      0.070      4.478      0.000       0.175       0.448
# Overperformance duration      0.0028      0.001      2.121      0.034       0.000       0.005
# Absorbed slack               -0.0309      0.058     -0.536      0.592      -0.144       0.082
# Unabsorbed slack              0.0308      0.006      5.448      0.000       0.020       0.042
# Absorptive capacity          -0.6333      0.151     -4.206      0.000      -0.928      -0.338
# Market commonality           -0.0491      0.040     -1.231      0.218      -0.127       0.029
# Size                          0.0085      0.007      1.230      0.219      -0.005       0.022
# Year                          0.0003      0.002      0.196      0.845      -0.003       0.003
# Intercept                    -0.6876      3.065     -0.224      0.822      -6.695       5.319
# ==============================================================================
# Omnibus:                      517.677   Durbin-Watson:                   1.978
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            93646.900
# Skew:                          -6.998   Prob(JB):                         0.00
# Kurtosis:                      80.212   Cond. No.                     9.72e+05
# ==============================================================================
#
# Notes:
# [1] Driscoll and Kraay Standard Errors are robust to cluster correlation (HAC-Groupsum)
# [2] The condition number is large, 9.72e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      Attentional focus   R-squared:                       0.170
# Model:                            OLS   Adj. R-squared:                  0.149
# Method:                 Least Squares   F-statistic:                     136.3
# Date:                Wed, 14 Jun 2023   Prob (F-statistic):           1.35e-25
# Time:                        10:45:27   Log-Likelihood:                 385.23
# No. Observations:                 365   AIC:                            -750.5
# Df Residuals:                     355   BIC:                            -711.5
# Df Model:                           9
# Covariance Type:         hac-groupsum
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Ambidextrous alliances        0.1006      0.016      6.229      0.000       0.069       0.132
# Overperformance magnitude     0.0882      0.038      2.307      0.021       0.013       0.163
# Overperformance duration     -0.0063      0.003     -2.510      0.012      -0.011      -0.001
# Absorbed slack                0.1285      0.016      7.885      0.000       0.097       0.160
# Unabsorbed slack             -0.0062      0.004     -1.736      0.083      -0.013       0.001
# Absorptive capacity          -0.0848      0.019     -4.392      0.000      -0.123      -0.047
# Market commonality           -0.1120      0.016     -7.212      0.000      -0.142      -0.082
# Size                         -0.0104      0.005     -2.149      0.032      -0.020      -0.001
# Year                         -0.0003      0.001     -0.643      0.520      -0.001       0.001
# Intercept                     1.2719      1.048      1.213      0.225      -0.783       3.327
# ==============================================================================
# Omnibus:                       28.435   Durbin-Watson:                   0.482
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               25.783
# Skew:                          -0.581   Prob(JB):                     2.52e-06
# Kurtosis:                       2.413   Cond. No.                     9.72e+05
# ==============================================================================
#
# Notes:
# [1] Driscoll and Kraay Standard Errors are robust to cluster correlation (HAC-Groupsum)
# [2] The condition number is large, 9.72e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                                 OLS Regression Results
# ======================================================================================
# Dep. Variable:     Underperformance magnitude   R-squared:                       0.378
# Model:                                    OLS   Adj. R-squared:                  0.360
# Method:                         Least Squares   F-statistic:                     257.4
# Date:                        Wed, 14 Jun 2023   Prob (F-statistic):           4.82e-31
# Time:                                10:45:27   Log-Likelihood:                 191.68
# No. Observations:                         365   AIC:                            -361.4
# Df Residuals:                             354   BIC:                            -318.5
# Df Model:                                  10
# Covariance Type:                 hac-groupsum
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Ambidextrous alliances        0.0319      0.011      2.924      0.003       0.011       0.053
# Attentional focus             0.1707      0.027      6.217      0.000       0.117       0.224
# Overperformance magnitude     0.2965      0.068      4.353      0.000       0.163       0.430
# Overperformance duration      0.0039      0.002      2.371      0.018       0.001       0.007
# Absorbed slack               -0.0529      0.059     -0.889      0.374      -0.169       0.064
# Unabsorbed slack              0.0319      0.005      5.873      0.000       0.021       0.043
# Absorptive capacity          -0.6188      0.149     -4.140      0.000      -0.912      -0.326
# Market commonality           -0.0300      0.039     -0.767      0.443      -0.107       0.047
# Size                          0.0103      0.007      1.467      0.142      -0.003       0.024
# Year                          0.0004      0.002      0.232      0.817      -0.003       0.003
# Intercept                    -0.9046      3.095     -0.292      0.770      -6.970       5.161
# ==============================================================================
# Omnibus:                      517.868   Durbin-Watson:                   1.992
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            94080.867
# Skew:                          -7.001   Prob(JB):                         0.00
# Kurtosis:                      80.396   Cond. No.                     9.73e+05
# ==============================================================================
#
# Notes:
# [1] Driscoll and Kraay Standard Errors are robust to cluster correlation (HAC-Groupsum)
# [2] The condition number is large, 9.73e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                           Estimate  Lower CI bound  Upper CI bound  P-value
# ACME (control)            0.017596       -0.000486        0.044922    0.058
# ACME (treated)            0.017596       -0.000486        0.044922    0.058
# ADE (control)             0.035827       -0.076000        0.148512    0.594
# ADE (treated)             0.035827       -0.076000        0.148512    0.594
# Total effect              0.053424       -0.058643        0.170281    0.398
# Prop. mediated (control)  0.178885       -2.852271        3.820444    0.436
# Prop. mediated (treated)  0.178885       -2.852271        3.820444    0.436
# ACME (average)            0.017596       -0.000486        0.044922    0.058
# ADE (average)             0.035827       -0.076000        0.148512    0.594
# Prop. mediated (average)  0.178885       -2.852271        3.820444    0.436

# %%
0.1*0.2
# Out:
# 0.020000000000000004

# %%
model0 = sm.OLS(XY['Underperformance duration'],X0)
est_model0 = model0.fit(cov_type='hac-groupsum',cov_kwds={'time':XY.set_index('Year').index,'maxlags':5})
print(est_model0.summary())
model1 = sm.OLS(XY['Attentional focus'],X0)
est_model1 = model1.fit(cov_type='hac-groupsum',cov_kwds={'time':XY.set_index('Year').index,'maxlags':5})
print(est_model1.summary())
model2 = sm.OLS(XY['Underperformance duration'],X)
est_model2 = model2.fit(cov_type='hac-groupsum',cov_kwds={'time':XY.set_index('Year').index,'maxlags':5})
print(est_model2.summary())
mediation = Mediation(model2,model1,'Ambidextrous alliances','Attentional focus').fit(n_rep=1000)
print(mediation.summary())
# Out:
#                                 OLS Regression Results
# =====================================================================================
# Dep. Variable:     Underperformance duration   R-squared:                       0.422
# Model:                                   OLS   Adj. R-squared:                  0.407
# Method:                        Least Squares   F-statistic:                     136.1
# Date:                       Wed, 14 Jun 2023   Prob (F-statistic):           1.39e-25
# Time:                               10:54:11   Log-Likelihood:                -1090.5
# No. Observations:                        365   AIC:                             2201.
# Df Residuals:                            355   BIC:                             2240.
# Df Model:                                  9
# Covariance Type:                hac-groupsum
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Ambidextrous alliances       -2.6290      1.480     -1.776      0.076      -5.530       0.272
# Overperformance magnitude    -8.3035      1.085     -7.651      0.000     -10.431      -6.176
# Overperformance duration     -0.1482      0.057     -2.601      0.009      -0.260      -0.036
# Absorbed slack               18.8011      4.851      3.875      0.000       9.293      28.310
# Unabsorbed slack             -1.3425      0.273     -4.910      0.000      -1.878      -0.807
# Absorptive capacity          -3.9543      1.716     -2.304      0.021      -7.318      -0.591
# Market commonality            4.8962      2.351      2.082      0.037       0.288       9.505
# Size                         -0.8977      0.236     -3.804      0.000      -1.360      -0.435
# Year                          0.2616      0.056      4.633      0.000       0.151       0.372
# Intercept                  -519.4534    110.648     -4.695      0.000    -736.319    -302.588
# ==============================================================================
# Omnibus:                      123.666   Durbin-Watson:                   0.656
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              460.634
# Skew:                           1.467   Prob(JB):                    9.43e-101
# Kurtosis:                       7.656   Cond. No.                     9.72e+05
# ==============================================================================
#
# Notes:
# [1] Driscoll and Kraay Standard Errors are robust to cluster correlation (HAC-Groupsum)
# [2] The condition number is large, 9.72e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      Attentional focus   R-squared:                       0.170
# Model:                            OLS   Adj. R-squared:                  0.149
# Method:                 Least Squares   F-statistic:                     136.3
# Date:                Wed, 14 Jun 2023   Prob (F-statistic):           1.35e-25
# Time:                        10:54:11   Log-Likelihood:                 385.23
# No. Observations:                 365   AIC:                            -750.5
# Df Residuals:                     355   BIC:                            -711.5
# Df Model:                           9
# Covariance Type:         hac-groupsum
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Ambidextrous alliances        0.1006      0.016      6.229      0.000       0.069       0.132
# Overperformance magnitude     0.0882      0.038      2.307      0.021       0.013       0.163
# Overperformance duration     -0.0063      0.003     -2.510      0.012      -0.011      -0.001
# Absorbed slack                0.1285      0.016      7.885      0.000       0.097       0.160
# Unabsorbed slack             -0.0062      0.004     -1.736      0.083      -0.013       0.001
# Absorptive capacity          -0.0848      0.019     -4.392      0.000      -0.123      -0.047
# Market commonality           -0.1120      0.016     -7.212      0.000      -0.142      -0.082
# Size                         -0.0104      0.005     -2.149      0.032      -0.020      -0.001
# Year                         -0.0003      0.001     -0.643      0.520      -0.001       0.001
# Intercept                     1.2719      1.048      1.213      0.225      -0.783       3.327
# ==============================================================================
# Omnibus:                       28.435   Durbin-Watson:                   0.482
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               25.783
# Skew:                          -0.581   Prob(JB):                     2.52e-06
# Kurtosis:                       2.413   Cond. No.                     9.72e+05
# ==============================================================================
#
# Notes:
# [1] Driscoll and Kraay Standard Errors are robust to cluster correlation (HAC-Groupsum)
# [2] The condition number is large, 9.72e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                                 OLS Regression Results
# =====================================================================================
# Dep. Variable:     Underperformance duration   R-squared:                       0.457
# Model:                                   OLS   Adj. R-squared:                  0.442
# Method:                        Least Squares   F-statistic:                     90.73
# Date:                       Wed, 14 Jun 2023   Prob (F-statistic):           6.50e-23
# Time:                               10:54:11   Log-Likelihood:                -1079.1
# No. Observations:                        365   AIC:                             2180.
# Df Residuals:                            354   BIC:                             2223.
# Df Model:                                 10
# Covariance Type:                hac-groupsum
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Ambidextrous alliances       -1.2169      1.541     -0.790      0.430      -4.238       1.804
# Attentional focus           -14.0318      1.313    -10.688      0.000     -16.605     -11.459
# Overperformance magnitude    -7.0658      0.754     -9.376      0.000      -8.543      -5.589
# Overperformance duration     -0.2363      0.036     -6.578      0.000      -0.307      -0.166
# Absorbed slack               20.6039      4.922      4.186      0.000      10.957      30.251
# Unabsorbed slack             -1.4295      0.303     -4.713      0.000      -2.024      -0.835
# Absorptive capacity          -5.1439      1.693     -3.037      0.002      -8.463      -1.825
# Market commonality            3.3253      2.101      1.583      0.114      -0.793       7.444
# Size                         -1.0443      0.249     -4.196      0.000      -1.532      -0.556
# Year                          0.2567      0.057      4.490      0.000       0.145       0.369
# Intercept                  -501.6063    111.840     -4.485      0.000    -720.809    -282.404
# ==============================================================================
# Omnibus:                      116.211   Durbin-Watson:                   0.717
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              508.538
# Skew:                           1.308   Prob(JB):                    3.74e-111
# Kurtosis:                       8.157   Cond. No.                     9.73e+05
# ==============================================================================
#
# Notes:
# [1] Driscoll and Kraay Standard Errors are robust to cluster correlation (HAC-Groupsum)
# [2] The condition number is large, 9.73e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                           Estimate  Lower CI bound  Upper CI bound  P-value
# ACME (control)           -1.406439       -2.731011       -0.347659    0.008
# ACME (treated)           -1.406439       -2.731011       -0.347659    0.008
# ADE (control)            -1.254531       -5.017720        2.644224    0.502
# ADE (treated)            -1.254531       -5.017720        2.644224    0.502
# Total effect             -2.660970       -6.712464        1.098155    0.186
# Prop. mediated (control)  0.451426       -4.522289        4.995348    0.186
# Prop. mediated (treated)  0.451426       -4.522289        4.995348    0.186
# ACME (average)           -1.406439       -2.731011       -0.347659    0.008
# ADE (average)            -1.254531       -5.017720        2.644224    0.502
# Prop. mediated (average)  0.451426       -4.522289        4.995348    0.186

# %%
0.1*-14
# Out:
# -1.4000000000000001
